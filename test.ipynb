# %%
import os
import time

import pandas as pd
import numpy as np
import requests
import json

# %%
os.getcwd()
# Out:
# 'D:\\work\\GithubDesktopWork\\weibo-crawler'

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36"
cookie = "SINAGLOBAL=2445087610963.819.1665800461200; UOR=,,login.sina.com.cn; ULV=1676729661806:11:10:3:6263974993731.194.1676729661785:1676377177394; SUBP=0033WrSXqPxfM725Ws9jqgMF55529P9D9WW-YeTu-qh4H34TngOL4inC5JpX5KMhUgL.FoMNeh-cSK-ES0q2dJLoI7yPqg4rBgvaqBtt; SCF=ArbxV094DLW9CGAftO3xt8-j4H9zln0zgPLdUdewyyhDd0fekP0JZ6pcn5tiZHe46Ve3TsTtHTBFZ1oV4pAK8CY.; SUB=_2A25O-y-SDeRhGeFJ61cX9SvOzDqIHXVqcQZarDV8PUNbmtAfLRXFkW9NfKYuS5LJZEYyn-ImvGoG4c3EtiamZKRt; ALF=1680272576; SSOLoginState=1677680578; XSRF-TOKEN=YLg1XnhEkAG_l_d6NHZOpaT5; WBPSESS=LoVr1S0y0cjXioOlbTPcRcN_vDABtWd2jYQzo0qP7EWhhD41X7dTplAeszHncMTh7_av3Fpi8jap-7hhjJ9x_Eom8z6aPYm0uHMZ3HUPhwnLzqEQ87Vgtnk3CC4Mc0qSGT_wL0s_CCNhxzL8NRwq2w=="
# cookie = ""
headers = {"User_Agent": user_agent, "Cookie": cookie}
id = 6274764018
id=7705655276
id = 6074526225

def get_json(url, params):
    """获取网页中json数据"""
    r = requests.get(url, params=params, headers=headers, verify=False)
    return r.json(), r.status_code
def json_save(file, data):
    with open(file, "w") as f:
        json.dump(data, f)

# %%
import os
os.getcwd()
# Out:
# 'D:\\work\\GithubDesktopWork\\weibo-crawler'

# %%
url = "https://m.weibo.cn/api/container/getIndex?containerid=100505{}".format(id)
url = "https://m.weibo.cn/api/container/getIndex?containerid=230283{}_-_INFO".format(id)
data= requests.get(url,  headers=headers)
print(data.status_code)
# data.json()['data']['userInfo']['statuses_count']
data.json()
# Out:
# 200
# {'ok': 1,
#  'data': {'cards': [{'card_type': 11,
#     'card_group': [{'card_type': 42, 'display_arrow': 0, 'desc': '账号信息'},
#      {'item_type': 'verify_yellow',
#       'display_arrow': 1,
#       'actionlog': {'act_code': '594',
#        'ext': 'uid:0|ouid:6074526225',
#        'oid': '2302836074526225_-_INFO',
#        'fid': '2302836074526225_-_INFO',
#        'cardid': '230283_-_WEIBO_INDEX_PROFILE_VERFIED_CARD',
#        'uicode': '10000198'},
#       'card_type': 41,
#       'item_content': '',
#       'scheme': 'http://verified.weibo.com/verify?luicode=10000011&lfid=2302836074526225_-_INFO',
#       'itemid': '2302836074526225_-_WEIBO_INDEX_PROFILE_VERFIED_CARD'},
#      {'card_type': 41, 'item_name': '简介', 'item_content': '暂无简介'}]},
#    {'card_type': 11,
#     'card_group': [{'card_type': 42, 'display_arrow': 0, 'desc': '个人信息'},
#      {'card_type': 41, 'item_name': '性别', 'item_content': '男'}]}],
#   'cardlistInfo': {'show_style': 1,
#    'can_shared': 0,
# ...

# %%
data = None
data is None
# Out:
# True

# %%
def test_have_weibo(id):
    url = "https://m.weibo.cn/api/container/getIndex?containerid=100505{}".format(id)
    data= requests.get(url,  headers=headers)
    if data.status_code == 200:
        json_data = data.json()
        if 'data' in json_data and 'userInfo' in json_data['data'] and 'statuses_count' in json_data['data']['userInfo'] and json_data['data']['userInfo']['statuses_count'] > 0:
            return True
    return False
test_have_weibo(id)
# Out:
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3400\2232928340.py in <module>
# ----> 1 None > 1
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'

# %%
data = data.json()
print("{}--{}".format(data['data']['userInfo']['id'], type(data['data']['userInfo']['id'])))                                    #id----int
print(data['data']['userInfo']['screen_name'])                                                                                  #name---str
print("{}--{}".format(data['data']['userInfo']['statuses_count'], type(data['data']['userInfo']['statuses_count'])))            #微博数---int
print(data['data']['userInfo']['description'])                                                                                  #描述-----str
print(data['data']['userInfo']['gender'])                                                                                       #性别-----str
print("{}--{}".format(data['data']['userInfo']['svip'], type(data['data']['userInfo']['svip'])))                                #是否vip---int
print("{}--{}".format(data['data']['userInfo']['follow_count'], type(data['data']['userInfo']['follow_count'])))                #关注数-----int
print("{}--{}".format(data['data']['userInfo']['followers_count'], type(data['data']['userInfo']['followers_count'])))          #粉丝数-----str
# Out:
# 1537790411--<class 'int'>
# M鹿M
# 1080--<class 'int'>
# 😂😂😂
# m
# 1--<class 'int'>
# 159--<class 'int'>
# 6300.4万--<class 'str'>

# %%
url = "https://m.weibo.cn/api/container/getIndex?containerid=1005056274764018"
data= requests.get(url,  headers=headers)
print(data.status_code)
data.json()
# Out:
# 200
# {'ok': 1,
#  'data': {'isVideoCoverStyle': 1,
#   'isStarStyle': 0,
#   'userInfo': {'id': 6274764018,
#    'screen_name': '甜口味的冰美式',
#    'profile_image_url': 'https://tvax1.sinaimg.cn/crop.0.0.1080.1080.180/006QEgLgly8h4ufiobqw2j30u00u0gni.jpg?KID=imgbed,tva&Expires=1676462115&ssig=bkd9ddFiQL',
#    'profile_url': 'https://m.weibo.cn/u/6274764018?uid=6274764018&luicode=10000011&lfid=1005056274764018',
#    'statuses_count': 26,
#    'verified': False,
#    'verified_type': -1,
#    'close_blue_v': False,
#    'description': '爱生活，爱自己',
#    'gender': 'f',
#    'mbtype': 2,
#    'svip': 0,
#    'urank': 4,
#    'mbrank': 2,
#    'follow_me': False,
#    'following': False,
#    'follow_count': 97,
#    'followers_count': '90',
#    'followers_count_str': '90',
#    'cover_image_phone': 'https://tva1.sinaimg.cn/crop.0.0.640.640.640/549d0121tw1egm1kjly3jj20hs0hsq4f.jpg',
#    'avatar_hd': 'https://wx1.sinaimg.cn/orj480/006QEgLgly8h4ufiobqw2j30u00u0gni.jpg',
#    'like': False,
# ...

# %%
url = "https://m.weibo.cn/api/container/getIndex?containerid=231051_-_followers_-_{}".format(id)
proxies = { "https" : "https://192.168.0.1:9999"}
data= requests.get(url,  headers=headers, verify=False)
file = "/home/wangao/weibo-crawler/followers.json"
json_save(file, data.json())
# Out:
# /home/wangao/anaconda3/envs/weiboSpider/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'm.weibo.cn'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
page = 1
url = "https://m.weibo.cn/api/container/getIndex?containerid=231051_-_followers_-_{}&page={}".format(id, page)
proxies = { "https" : "https://192.168.0.1:9999"}
data= requests.get(url,  headers=headers, verify=False)
file = "/home/wangao/weibo-crawler/followers_{}.json".format(page)
# json_save(file, data.json())
data.json()
# Out:
# D:\worksoftware\Anaconda\envs\weiboSpider\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'ok': 1,
#  'data': {'cardlistInfo': {'containerid': '231051_-_followers_-_6274764018',
#    'title_top': '她的好友',
#    'show_style': '1',
#    'total': 70,
#    'page': 2},
#   'cards': [{'card_style': 1,
#     'card_type': 11,
#     'itemid': '',
#     'card_group': [{'card_type': 42,
#       'scheme': 'https://m.weibo.cn/p/index?containerid=231051_-_followerstagrecomm_-_6274764018_-_1042015%3AtagCategory_050&luicode=10000011&lfid=231051_-_followers_-_6274764018',
#       'display_arrow': 1,
#       'title_extra_text': '查看',
#       'itemid': '2310511026_1_ _6274764018',
#       'desc': '她关注了17个娱乐明星博主',
#       'actionlog': {'act_code': 695,
# ...

# %%
id = 1537790411
page = 0
url = "https://m.weibo.cn/api/container/getIndex?containerid=231051_-_fans_-_{}&since_id={}".format(id, page)
proxies = { "https" : "https://192.168.0.1:9999"}
data= requests.get(url,  headers=headers, verify=False)
file = "/home/wangao/weibo-crawler/fans_{}.json".format(page)
json_save(file, data.json())
print(data.status_code)
data.json()
# Out:
# /home/wangao/anaconda3/envs/weiboSpider/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'm.weibo.cn'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 200
# {'ok': 1,
#  'data': {'cardlistInfo': {'containerid': '231051_-_fans_-_1537790411',
#    'title_top': '他的好友',
#    'show_style': '1',
#    'since_id': 40},
#   'cards': [{'card_type': 11,
#     'itemid': '2310510033_1_ _1537790411',
#     'card_group': [{'card_type': 10,
#       'itemid': '2310510033_1_ _7820632296',
#       'scheme': 'https://m.weibo.cn/u/7820632296?uid=7820632296&luicode=10000011&lfid=231051_-_fans_-_1537790411',
#       'background_color': 0,
#       'openurl': '',
#       'recom_remark': '',
#       'recommend': '',
#       'desc1': '',
#       'desc2': '',
#       'user': {'id': 7820632296,
# ...

# %%
data.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='XSRF-TOKEN', value='3d5320', port=None, port_specified=False, domain='.m.weibo.cn', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1676368351, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='MLOGIN', value='0', port=None, port_specified=False, domain='.weibo.cn', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1676370751, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='M_WEIBOCN_PARAMS', value='fid%3D231051_-_fans_-_1537790411%26uicode%3D10000011', port=None, port_specified=False, domain='.weibo.cn', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1676367751, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='WEIBOCN_FROM', value
# ...

# %%
data = pd.DataFrame({'id':[i for i in range(5)], 'name':[i for i in range(5)]})
data
# Out:
#    id  name
# 0   0     0
# 1   1     1
# 2   2     2
# 3   3     3
# 4   4     4

# %%
import random
random.random()
# Out:
# 0.3838848000806473

# %%
url = "https://m.weibo.cn/api/container/getIndex?containerid=231051_-_fans_-_6112596837&since_id=0"
data= requests.get(url,  headers=headers)
print(data.status_code)
data = data.json()
data['data']['cards'][1]['card_group'][2]
# Out:
# 200
# {'card_type': 10,
#  'itemid': '2310510033_1_ _2919947200',
#  'scheme': 'https://m.weibo.cn/u/2919947200?uid=2919947200&luicode=10000011&lfid=231051_-_fans_-_6112596837',
#  'background_color': 0,
#  'openurl': '',
#  'recom_remark': '',
#  'recommend': '',
#  'desc1': '',
#  'desc2': '',
#  'user': None,
#  'actionlog': {'act_code': 695,
#   'cardid': '2310510033_1_ _2919947200',
#   'oid': 2919947200,
#   'featurecode': '',
#   'mark': '',
#   'ext': 'act:skip|act_valu:sinaweibo://userinfo?uid=2919947200|uid:6008529703|follow:2919947200|skiptype:profile',
#   'uicode': '',
#   'luicode': '',
#   'fid': '',
#   'lfid': '',
#   'lcardid': ''},
#  'buttons': [{'type': 'follow',
#    'sub_type': 0,
#    'name': '关注',
#    'skip_format': 1,
#    'params': {'uid': 2919947200,
#     'need_follow': 1,
#     'trend_ext': 2919947200,
#     'trend_type': 42,
#     'itemid': 2919947200},
#    'actionlog': {'act_code': 1338,
#     'cardid': '2310510033_1_ _2919947200',
#     'oid': '',
# ...

# %%
data = np.load("./weiboData_10000/1900232583/basic_info/candidate_id_list.npy")
len(data)
# Out:
# 91

# %%
test_have_weibo(data[0])
# Out:
# True

# %%
data.tolist()
# Out:
# [1842357963,
#  5488316427,
#  7745795288,
#  1275402733,
#  1304432225,
#  7816789988,
#  6441220630,
#  5384179087,
#  5227617391,
#  1505299540,
#  5624298918,
#  6960931282,
#  6309029682,
#  7510880453,
#  6605705858,
#  5999631861,
#  1095240537,
#  1751878605,
#  6490014062,
#  1253587884,
#  7745058738,
#  2202410203,
#  2936943105,
#  6318319468,
#  1745358631,
#  7811570005,
#  1481589195,
#  2428300920,
#  2242069154,
#  2802495850,
#  6373143061,
#  6212814293,
#  7497027451,
#  6483560189,
#  1761738991,
#  2126779137,
#  3924697761,
#  1948301550,
#  3033663065,
#  1769423664,
#  7412475888,
#  3135024891,
#  6452596551,
#  1695957340,
#  7548639008,
#  3486494780,
#  1780219901,
#  2673774981,
#  3044604767,
#  1403839663,
#  7563895461,
#  5224329123,
#  6089551348,
#  7752720304,
#  7684500613,
#  1409302952,
#  7316147774,
#  3413618422,
#  1870508925,
#  1272198134,
#  2171301395,
#  5406556458,
#  2783037613,
#  2749040931,
#  5546199636,
#  7746856591,
# ...

# %%
count = data.tolist()[-1]
print(count)
print(data.tolist()[:-1])
# Out:
# 18
# ...

# %%
data = [5,4,3,2,1,0]
count = 0


while(True):
    count+=1
    time.sleep(5)
    try:
        temp = data[0]
        data = data[1:]
        print(data)
        1 / 0
    except Exception as e:
        print(e)
        print(temp)
# Out:
# [4, 3, 2, 1, 0]
# division by zero
# 5
# [3, 2, 1, 0]
# division by zero
# 4
# [2, 1, 0]
# division by zero
# 3
# [1, 0]
# division by zero
# 2
# [0]
# division by zero
# 1
# []
# division by zero
# 0
# list index out of range
# 0
# list index out of range
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3400\2112462588.py in <module>
#       5 while(True):
#       6     count+=1
# ----> 7     time.sleep(5)
#       8     try:
#       9         temp = data[0]
#
# KeyboardInterrupt:

# %%
[1] + [2,3]
# Out:
# [1, 2, 3]

# %%
data = np.load("./weiboData_10000/1900232583/basic_info/candidate_id_list.npy")
data = data[1:]
np.save("./weiboData_10000/1900232583/basic_info/candidate_id_list.npy", data)

# %%
data = np.load("./weiboData_10000/1900232583/basic_info/candidate_id_list.npy")
data[0]
# Out:
# 7538261151

# %%
len(data)
# Out:
# 24784
